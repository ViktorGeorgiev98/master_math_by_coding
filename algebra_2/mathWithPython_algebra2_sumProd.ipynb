# %% [markdown]
# # COURSE: Master math by coding in Python
# # SECTION: Algebra 2
# # VIDEO: Summation and products
#
#
# ### https://www.udemy.com/course/math-with-python/?couponCode=202312
# #### INSTRUCTOR: Mike X Cohen (http://sincxpress.com)
#
# This code roughly matches the code shown in the live recording: variable names, order of lines, and parameter settings may be slightly different.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/mikexcohen/MathWithPython/blob/main/algebra_2/mathWithPython_algebra2_sumProd.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# import libraries and functions
import sympy as sym
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %% [markdown]
# # VIDEO: Summation and products

# %%
lst = [1,3,4,1,6]

print( sum(lst) )
print( np.sum(lst) )
# Out:
# 15
# 15

# %%
np.prod(lst)
plt.plot(lst, "bo-")

# %%
# cumulative summation
np.cumsum(lst)

plt.plot(lst,'rs-')
plt.plot(np.cumsum(lst),'bo-')
plt.legend({'list','cumsum'})
plt.show()

# %%
a = np.array([1, 2, 3, 4, 5])
denominator = a ** 2
sum1 = np.sum(a)
sum2 = np.sum(denominator)
mult1 = np.prod(a)
mult2 = np.prod(denominator)
sum_equal = (sum1 / sum2) == (1 / sum1)
display(Math(f"\\frac{{{sum1}}}{{{sum2}}} = \\frac{{1}}{{{sum1}}} \\text{{ is }}{sum_equal}"))
display(Math(f"\\frac{{{mult1}}}{{{mult2}}} = \\frac{{1}}{{{mult1}}} \\text{{ is }}{(mult1 / mult2) == (1 / mult1)}"))
# Out:
# $\displaystyle \frac{15}{55} = \frac{1}{15} \text{ is }False$
# $\displaystyle \frac{120}{14400} = \frac{1}{120} \text{ is }True$

# %% [markdown]
# # Exercises

# %%
# generate numerator
num = np.arange(1,6)
den = num**2

ans1 = np.sum(num) / np.sum(den)
ans2 = 1 / np.sum(num)

print('Option 1 = %s\nOption 2 = %s' %(ans1,ans2))
# Out:
# Option 1 = 0.2727272727272727
# Option 2 = 0.06666666666666667

# %%
# then repeat with prod
ans1 = np.prod(num) / np.prod(den)
ans2 = 1 / np.prod(num)

print('Option 1 = %s\nOption 2 = %s' %(ans1,ans2))
# Out:
# Option 1 = 0.008333333333333333
# Option 2 = 0.008333333333333333
